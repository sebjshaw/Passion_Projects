# %% [markdown]
# # ATP_Matches_2021 Tennis Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

df = pd.read_csv('atp_matches_2021.csv')

# %%
# converting the date into a datetime data type 

df = df.astype({'tourney_date':'string'})
df.tourney_date = pd.to_datetime(df.tourney_date)

# %%
# save the olympics as a separate dataframe
df_olympics = df[df.tourney_name == 'Tokyo Olympics']
df_olympics
# Out:
#    tourney_id    tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 1   2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 2   2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 3   2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 4   2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# ..        ...             ...     ...        ...           ...          ...
# 59  2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 60  2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 61  2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 62  2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 63  2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
#
#     match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0         237     126207          NaN          NaN  ...     NaN      NaN
# 1         238     105526          NaN          NaN  ...     NaN      NaN
# 2         239     111576          NaN          NaN  ...     NaN      NaN
# 3         240     105357          NaN          NaN  ...     NaN      NaN
# 4         241     207830          NaN          NaN  ...     NaN      NaN
# ..        ...        ...          ...          ...  ...     ...      ...
# 59        296     104925          1.0          NaN  ...     NaN      NaN
# 60        297     111575         12.0          NaN  ...     NaN      NaN
# 61        298     100644          4.0          NaN  ...     NaN      NaN
# 62        299     100644          4.0          NaN  ...     NaN      NaN
# 63        300     105807          6.0          NaN  ...     NaN      NaN
#
#     l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0        NaN     NaN        NaN        NaN         53.0             1228.0
# 1        NaN     NaN        NaN        NaN         48.0             1410.0
# 2        NaN     NaN        NaN        NaN        160.0              471.0
# 3        NaN     NaN        NaN        NaN         44.0             1476.0
# 4        NaN     NaN        NaN        NaN        145.0              525.0
# ..       ...     ...        ...        ...          ...                ...
# 59       NaN     NaN        NaN        NaN          1.0            12113.0
# 60       NaN     NaN        NaN        NaN         25.0             2235.0
# 61       NaN     NaN        NaN        NaN          5.0             7340.0
# 62       NaN     NaN        NaN        NaN          5.0             7340.0
# 63       NaN     NaN        NaN        NaN         11.0             3260.0
#
#    loser_rank loser_rank_points
# 0        71.0             996.0
# 1        95.0             829.0
# 2       197.0             354.0
# 3        61.0            1106.0
# 4       137.0             570.0
# ..        ...               ...
# 59       69.0            1003.0
# 60       11.0            3260.0
# 61        1.0           12113.0
# 62       25.0            2235.0
# 63        1.0           12113.0
#
# [64 rows x 49 columns]

# %%
# remove the olympics from the overall dataframe 
df = df.drop(df[df.tourney_name == 'Tokyo Olympics'].index)

# %%
df.groupby('tourney_level')['tourney_level'].count()
# Out:
# tourney_level
# A    1505
# D     129
# F      15
# G     508
# M     512
# Name: tourney_level, dtype: int64

# %% [markdown]
# ### Tourney Level Codes
# * A = Olympics, ATP 250, ATP 500
# * D = Davis Cup
# * F = ATP Finals
# * G = Grand Slam
# * M = ATP Masters

# %%
df = df.sort_values(by ='tourney_date')
df = df.reset_index()
df
# Out:
#       level_0  index                       tourney_id  \
# 0           0   1161                        2021-0499
# 1          26   1158                        2021-0499
# 2          25   1159                        2021-0499
# 3          24   1160                        2021-0499
# 4          23   1162                        2021-0499
# ...       ...    ...                              ...
# 2664     2664   2634  2021-M-DC-2021-FLS-M-CRO-SRB-01
# 2665     2665   2642  2021-M-DC-2021-FLS-M-RTF-GER-01
# 2666     2666   2643  2021-M-DC-2021-FLS-M-RTF-GER-01
# 2667     2667   2640  2021-M-DC-2021-FLS-M-RTF-CRO-01
# 2668     2668   2641  2021-M-DC-2021-FLS-M-RTF-CRO-01
#
#                          tourney_name surface  draw_size tourney_level  \
# 0                        Delray Beach    Hard         32             A
# 1                        Delray Beach    Hard         32             A
# 2                        Delray Beach    Hard         32             A
# 3                        Delray Beach    Hard         32             A
# 4                        Delray Beach    Hard         32             A
# ...                               ...     ...        ...           ...
# 2664  Davis Cup Finals SF: CRO vs SRB    Hard          2             D
# 2665  Davis Cup Finals SF: RTF vs GER    Hard          2             D
# 2666  Davis Cup Finals SF: RTF vs GER    Hard          2             D
# 2667   Davis Cup Finals F: RTF vs CRO    Hard          2             D
# 2668   Davis Cup Finals F: RTF vs CRO    Hard          2             D
#
#      tourney_date  match_num  winner_id  ...  l_1stIn l_1stWon l_2ndWon  \
# 0      2021-01-04        275     111815  ...     28.0     13.0      7.0
# 1      2021-01-04        271     106329  ...     42.0     25.0     12.0
# 2      2021-01-04        272     200624  ...     29.0     22.0     11.0
# 3      2021-01-04        273     126205  ...     27.0     16.0     10.0
# 4      2021-01-04        276     106216  ...     32.0     17.0      7.0
# ...           ...        ...        ...  ...      ...      ...      ...
# 2664   2021-12-03          1     127339  ...     63.0     34.0     14.0
# 2665   2021-12-04          1     126094  ...     21.0     12.0     10.0
# 2666   2021-12-04          2     106421  ...     34.0     29.0      7.0
# 2667   2021-12-05          1     126094  ...     52.0     33.0     20.0
# 2668   2021-12-05          2     106421  ...     38.0     31.0      9.0
#
#      l_SvGms  l_bpSaved l_bpFaced  winner_rank  winner_rank_points  \
# 0        7.0        4.0       8.0         74.0               877.0
# 1       11.0        2.0       6.0         84.0               820.0
# 2       10.0        1.0       4.0        119.0               566.0
# 3        8.0        2.0       6.0         52.0              1080.0
# 4        8.0        2.0       6.0        274.0               195.0
# ...      ...        ...       ...          ...                 ...
# 2664    13.0        4.0       9.0        279.0               196.0
# 2665     8.0        0.0       4.0          5.0              5150.0
# 2666    10.0        3.0       5.0          2.0              8640.0
# 2667    11.0        7.0       8.0          5.0              5150.0
# 2668    10.0        1.0       3.0          2.0              8640.0
#
#       loser_rank loser_rank_points
# 0          299.0             165.0
# 1          281.0             185.0
# 2           95.0             768.0
# 3          268.0             205.0
# 4          304.0             154.0
# ...          ...               ...
# 2664        33.0            1591.0
# 2665        54.0            1101.0
# 2666        51.0            1134.0
# 2667       279.0             196.0
# 2668        30.0            1710.0
#
# [2669 rows x 51 columns]
